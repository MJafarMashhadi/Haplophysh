# %%
import numpy as np
from matplotlib import pyplot as plt


plt.plot(
    np.load("fpr_tpr/fccl-fpr.npy"),
    np.load("fpr_tpr/fccl-tpr.npy"),
    label=f'Fully Convolutional Character (area = 0.994)'  # Dirty hack
)
plt.plot(
    np.load("fpr_tpr/fcwl-fpr.npy"),
    np.load("fpr_tpr/fcwl-tpr.npy"),
    label=f'Fully Convolutional Word (area = 0.973)'
)
plt.plot(
    np.load("fpr_tpr/fccombi-fpr.npy"),
    np.load("fpr_tpr/fccombi-tpr.npy"),
    label=f'Fully Convolutional Word+Char (area = 0.996)'
)
plt.plot(
    np.load("fpr_tpr/rnn-fpr.npy"),
    np.load("fpr_tpr/rnn-tpr.npy"),
    label=f'RNN (area = 0.993)'
)


plt.title(f'ROC curves')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')
plt.savefig(f'../plots/combined_roc.pdf')
plt.show()
